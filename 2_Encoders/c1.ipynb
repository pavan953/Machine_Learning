# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = {
    "fruits" : ["Orange", "Apple","Orange", "Banana","Apple","Apple","Banana","Orange","Banana","Apple"],
    "Initial" : ["o","a","o","b","a","a","b","o","b","a"]
}

df = pd.DataFrame(data)
df
# Out:
#    fruits Initial
# 0  Orange       o
# 1   Apple       a
# 2  Orange       o
# 3  Banana       b
# 4   Apple       a
# 5   Apple       a
# 6  Banana       b
# 7  Orange       o
# 8  Banana       b
# 9   Apple       a

# %%
encoder = LabelEncoder()

# %%
# encoded_values = encoder.fit_transform(df[["fruits","Initial"]])
# ValueError: y should be a 1d array, got an array of shape (10, 2) instead.

# %%
encoder.fit_transform(df["fruits"])
# Out:
# array([2, 0, 2, 1, 0, 0, 1, 2, 1, 0])

# %%
encoder.transform(["Banana"])
# Out:
# array([1])

# %%
encoder.fit_transform(df["Initial"])
# Out:
# array([2, 0, 2, 1, 0, 0, 1, 2, 1, 0])

# %%
encoder.transform(df["Initial"])
# Out:
# array([2, 0, 2, 1, 0, 0, 1, 2, 1, 0])
