# %%
import pandas as pd
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/preet/Desktop/ML/Datasets/standardscaler_ss_.csv")
df.head()
# Out:
#    Experience_Years    Age  Education_Level  Hours_Per_Week     Salary
# 0              5.99  34.63                3           41.12   87638.54
# 1              4.72  39.55                4           46.82   84956.80
# 2              6.30  23.01                1           40.63   73501.52
# 3              8.05  32.81                4           37.85  100707.27
# 4              4.53  26.75                3           40.61   80094.46

# %%
x = df.drop(columns=["Salary"])
y = df["Salary"]

# %%
xtrain, xtest, ytrain,ytest = train_test_split(x,y, train_size=0.8, random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
model.coef_
# Out:
# array([4202.9561495 ,  144.39478967, 4927.27044829,  142.90100371])

# %%
model_ridge = Ridge()
model_ridge.fit(xtrain, ytrain)
model_ridge.coef_
# Out:
# array([4199.83507918,  144.24450962, 4916.96091533,  142.99501065])

# %%
model_lasso = Lasso()
model_lasso .fit(xtrain, ytrain)
model_lasso.coef_
# Out:
# array([4202.66068941,  144.33984748, 4926.4257234 ,  142.871653  ])

# %%
model_elasticnet = ElasticNet()
model_elasticnet.fit(xtrain, ytrain)
model_elasticnet.coef_
# Out:
# array([3669.60668956,  120.52022012, 3463.97378774,  156.97746179])
