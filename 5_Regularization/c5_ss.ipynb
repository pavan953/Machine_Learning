# %%
import pandas as pd
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/preet/Desktop/ML/Datasets/standardscaler_ss.csv")
df.head()
# Out:
#    Feature1  Feature2      Feature3         Target
# 0         7    506815  78179.054805  147107.322662
# 1         4    293822  70538.588873  127684.231772
# 2         8     77218  44636.920014   87982.249559
# 3         5    588518  86421.631346  166046.587018
# 4         7    771044  55814.069145  101011.603738

# %%
x = df.drop(columns=["Target"])
y = df["Target"]

# %%
xtrain, xtest, ytrain,ytest = train_test_split(x,y, train_size=0.8, random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
model.coef_
# Out:
# array([-1.90917070e+01,  2.55230384e-04,  1.79990677e+00])

# %%
model_ridge = Ridge()
model_ridge.fit(xtrain, ytrain)
model_ridge.coef_
# Out:
# array([-1.90880768e+01,  2.55231858e-04,  1.79990679e+00])

# %%
model_lasso = Lasso()
model_lasso .fit(xtrain, ytrain)
model_lasso.coef_
# Out:
# array([-1.89395634e+01,  2.55292155e-04,  1.79990786e+00])

# %%
model_elasticnet = ElasticNet()
model_elasticnet.fit(xtrain, ytrain)
model_elasticnet.coef_
# Out:
# array([-1.76713230e+01,  2.55807211e-04,  1.79991693e+00])
