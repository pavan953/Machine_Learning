# %%
import pandas as pd
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/preet/Desktop/ML/Datasets/standard_scaler_dataset_ssd.csv")
df.head()
# Out:
#    Age  Salary  Experience
# 0   56   32695           3
# 1   46   78190           7
# 2   32   35258           6
# 3   60  117538           8
# 4   25   69504          27

# %%
x = df.drop(columns=["Experience"])
y = df["Experience"]

# %%
xtrain, xtest, ytrain,ytest = train_test_split(x,y, train_size=0.8, random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
model.coef_
# Out:
# array([5.55536133e-02, 3.62983445e-05])

# %%
model_ridge = Ridge()
model_ridge.fit(xtrain, ytrain)
model_ridge.coef_
# Out:
# array([5.55502545e-02, 3.62983341e-05])

# %%
model_lasso = Lasso()
model_lasso .fit(xtrain, ytrain)
model_lasso.coef_
# Out:
# array([5.07164276e-02, 3.62825600e-05])

# %%
model_elasticnet = ElasticNet()
model_elasticnet.fit(xtrain, ytrain)
model_elasticnet.coef_
# Out:
# array([5.30068189e-02, 3.62900565e-05])
