# %%
import pandas as pd
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/preet/Desktop/ML/Datasets/Salary_dataset_sd.csv")
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x = df.drop(columns=["Salary"])
y = df["Salary"]

# %%
xtrain, xtest, ytrain,ytest = train_test_split(x,y, train_size=0.8, random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
model.coef_
# Out:
# array([ -852.62599488, 12045.97955622])

# %%
model_ridge = Ridge()
model_ridge.fit(xtrain, ytrain)
model_ridge.coef_
# Out:
# array([ -225.26028   , 10066.05458105])

# %%
model_lasso = Lasso()
model_lasso .fit(xtrain, ytrain)
model_lasso.coef_
# Out:
# array([ -850.61882935, 12039.68625742])

# %%
model_elasticnet = ElasticNet(l1_ratio=0.3)
model_elasticnet.fit(xtrain, ytrain)
model_elasticnet.coef_
# Out:
# array([1692.97626657, 3977.59667168])
